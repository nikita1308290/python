# %%
import cv2
import matplotlib.pyplot as plt

# %%
image= cv2.imread(r"C:\Users\Asus\OneDrive\Desktop\python\datascience\top 25 countries with immigration.png")

# %%
plt.imshow(image)

# %%
cv2.imshow("ur image",image)
cv2.waitKey()
# Out:
# -1
